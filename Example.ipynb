# %%
import sys
path = '/Users/rikclaes/python/functions'
sys.path.remove(path)  
#PATH = '/Users/rikclaes/python/functions/MyFitter/FrappePackage/'
#sys.path = [PATH] + sys.path
print(sys.path)



from src.frappe import Frappe
import matplotlib.pyplot as plt

# %matplotlib qt
#ipython --pylab -c "%run /Users/rclaes/python/functions/MyFitter/the_ultimate_fitter_nir_PENELLOPE_xs_py3_contGrid_EarlyK_norm733_CHAI -obj Gaia23_burst -dist 900. -f_uvb /Users/rclaes/Downloads/PeakOutburst/GAIA23bab_Peak_UVB.fits -f_vis /Users/rclaes/Downloads/PeakOutburst/GAIA23bab_Peak_VIS.fits -f_nir /Users/rclaes/Downloads/PeakOutburst/GAIA23bab_Peak_NIR.fits -cl3 3.0 -Av 4.4 -perAA -fitsTab -Rv 5.5"
dirSpec = '/Users/rikclaes/Documents/Work/ChaI/CHX18N/XS/'
fileUVB = 'flux_CHX18N_ep2_uvb.fits'
fileVIS = 'flux_CHX18N_ep2_vis_tell.fits'
fileNIR = 'flux_CHX18N_ep2_nir_tell.fits'
obj_in = 'CHX18N_ep2'
dist = 192
dirOut = '/Users/rikclaes/python/functions/MyFitter/FrappePackage/tests/'
#Av = [4.0,4.1,4.2,4.3,4.4,4.5,4.6,4.7,4.8,4.9,5,5.1,5.2,5.3,5.5,5.7,6]
#spt = [-2,-1,0,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,5.5,6,6.5,7,8,9]
Av = [0.7,0.8,0.9,1.0,1.1,1.2,1.3,1.4,1.5,1.6]
spt = [0,0.5]
Av = [1.6]
spt = [-6.0]
f2 = Frappe.Fit(dirSpec+fileUVB,
                 dirSpec+fileVIS,
                 dirSpec+fileNIR,
                 obj_in,
                 dist,
                 dirOut,
                 spt = spt,
                 Av = Av,
                 fitsTab =False)


f2.writeCSV()
f2.resultsToFile()

#if Fileout = None places a table in dirOut, otherwise will write a line in FileOut
f2.addEntryToTable(FileOut = None)

f2.plotRegFit(close = False)
f2.plotAll(CLIII = False,smooth = False, close = False)
f2.plotPaschen(CLIII =False,close = False)
f2.plotVeil(close =False)

f2.Chi2SpT()
f2.Chi2Av()
f2.Chi2AvAndSpT()
f2.Chi2AvAndSpT_Posterior()
# Out:
# ['/opt/anaconda3/envs/FrappeEnv3/lib/python310.zip', '/opt/anaconda3/envs/FrappeEnv3/lib/python3.10', '/opt/anaconda3/envs/FrappeEnv3/lib/python3.10/lib-dynload', '', '/opt/anaconda3/envs/FrappeEnv3/lib/python3.10/site-packages']
# /Users/rikclaes/python/functions/MyFitter/FrappePackage/src/frappe
# here
# /Users/rikclaes/python/functions/MyFitter/FrappePackage/tests/CHX18N_ep2_2025-05-13_15.13.19
# CHX18N_ep2
# [1.6]
# [1.6]
# You have given a selection of spectral types
# working_dir   /Users/rikclaes/python/functions/MyFitter/FrappePackage/src/frappe/models_grid/
# 2025-05-13 15:13:20,444	INFO worker.py:1888 -- Started a local Ray instance.
# 2025-05-13 15:13:20,484	INFO packaging.py:576 -- Creating a file package for local module '/Users/rikclaes/python/functions/MyFitter/FrappePackage'.
# 2025-05-13 15:13:20,533	INFO packaging.py:368 -- Pushing file package 'gcs://_ray_pkg_3d44e086c7e63219.zip' (2.51MiB) to Ray cluster...
# 2025-05-13 15:13:20,549	INFO packaging.py:381 -- Successfully pushed file package 'gcs://_ray_pkg_3d44e086c7e63219.zip'.
# (main_process pid=1550) /private/tmp/ray/session_2025-05-13_15-13-19_345293_1524/runtime_resources/working_dir_files/_ray_pkg_3d44e086c7e63219/src/frappe
# (main_process pid=1550) NOT POSSIBLE
# Execution time: 15.704814195632935  seconds
#
#
# ---------------
# ---------------
# BEST CHI SQUARED:  3.471659858980772
#
# PARAMETERS OF BEST FIT: ClassIII = -6.0 , Av= 1.6 , T= 6500 , Ne= 1e+11 , tau= 5
# NORMALIZATION CONSTANTS FOR THE BEST FIT: H= [4.05162314e-21] , K= [1.77540253e-12]
# ---------------
# ---------------
# MA PERCHE???????????
# MA PERCHE???????????
# NUMBER OF LINES IN THE FILE:  3981
# BAD LINES:
# 9
# GOOD LINES:
# 3972
# [0.0379943]
# [0.0379943]
# NUMBER OF LINES IN THE FILE:  3981
# BAD LINES:
# 9
# GOOD LINES:
# 3972
# [0.0379943]
# [0.0379943]
# NUMBER OF LINES IN THE FILE:  3981
# BAD LINES:
# 9
# GOOD LINES:
# 3972
# !!!!!
# RXJ0438.6+1546_penellope
# !!!!!
# NUMBER OF LINES IN THE FILE:  3981
# BAD LINES:
# 9
# GOOD LINES:
# 3972
# !!!!!
# RXJ0438.6+1546_penellope
# !!!!!
# NUMBER OF LINES IN THE FILE:  3981
# BAD LINES:
# 9
# GOOD LINES:
# 3972
# !!!!!
# RXJ0438.6+1546_penellope
# !!!!!
# NUMBER OF LINES IN THE FILE:  3981
# BAD LINES:
# 9
# GOOD LINES:
# 3972
# !!!!!
# RXJ1608.9-3905
# !!!!!
